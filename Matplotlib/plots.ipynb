# %%
import matplotlib.pyplot as plt

# %%
year = [2010, 2011, 2012, 2013, 2014, 2015, 2016]
pop = [340, 450, 530, 690, 780, 850, 960]

# %%
plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year, pop)
plt.show()
